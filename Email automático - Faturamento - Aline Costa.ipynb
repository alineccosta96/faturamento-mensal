# %% [markdown]
# Passo 1 - Entrar no sistema da empresa (Entrar no link: https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing)
#
# Passo 2 - Navegar até o local da nossa base de dados (Entrar na pasta "Exportar")
#
# Passo 3 - Baixar a planilha de vendas, e analisar
#
# Passo 4 - Calcular o faturamento e quantidade de produtos vendidos da base
#
# Passo 5 - Enviar email para Diretoria com a quantidade e o faturamento que calculamos.

# %%
import pyautogui
import time
import pyperclip
import pandas as pd

#DICA: SEMPRE USAR O COPY PARA NÃO TER PROBLEMA DE PREENCHIMENTO AUTOMÁTICO

#Pausa de 1 segundo entre os comandos
pyautogui.PAUSE = 1 

# Passo 1
pyautogui.hotkey("ctrl", "t")
Sistema = 'https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing'
pyperclip.copy(Sistema)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("ctrl", "enter")

# Passo 2
time.sleep(5)
#pyautogui.position() retornou 324,289
#Selecrionar a pasta 'Explorar' e clicar 2x
pyautogui.click(324,289,clicks=2) 

#Passo 3
time.sleep(3)
#Selecionar o arquivos vendas 1x
pyautogui.click(324,289,clicks=1) 
time.sleep(3)
#Selecionar os três pontinhos
#pyautogui.position() 
pyautogui.click(1158,195,clicks=1) 
#Selecionar 'Download'
#pyautogui.position() 
pyautogui.click(1013,592,clicks=1) 
time.sleep(5)
import pandas as pd
#Passo 4
tabela = pd.read_excel(r"C:\Users\ALINE\Downloads\Vendas - Dez.xlsx")
faturamento = tabela["Valor Final"].sum()
quantidade  = tabela["Quantidade"].sum()
##display(tabela)

#Passo 5
pyautogui.hotkey("ctrl", "t")
LinkGmail = 'https://mail.google.com/mail/u/0/?tab=rm&ogbl'
pyperclip.copy(LinkGmail)
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("ctrl","enter")
time.sleep(8)
###pyautogui.position() Pegar a posição do botão escrever
pyautogui.click(68,199,clicks=1)
#Escrever o email
email = "alineccosta96@gmail.com"
pyperclip.copy(email)
pyautogui.hotkey("ctrl","v")
pyautogui.press("tab")
Assunto = "Relatório de vendas"
pyperclip.copy(Assunto)
pyautogui.hotkey("ctrl","v")
pyautogui.press("tab")
Texto = f"""Olá,
O faturamento da empresa foi de: R${faturamento:,.2f}
A quantidade de produto vendida foi de: {quantidade:,}

Obrigada,
Aline Costa
"""
pyperclip.copy(Texto)
pyautogui.hotkey("ctrl","v")

pyautogui.hotkey("ctrl","enter")
